# %%
import pandas as pd
data={'transaction_id':[1,2,3,4,5],
        'category':['Food','Clothing','Food','Entertainment','Clothing'],
        'Amount':[10,20,15,None,25]}

df=pd.DataFrame(data)
print(df)
df['Amount']=df['Amount'].fillna(0)
total=df['Amount'].sum()
print("Total Amount:",total)
# Out:
#    transaction_id       category  Amount
# 0               1           Food    10.0
# 1               2       Clothing    20.0
# 2               3           Food    15.0
# 3               4  Entertainment     NaN
# 4               5       Clothing    25.0
# Total Amount: 70.0
